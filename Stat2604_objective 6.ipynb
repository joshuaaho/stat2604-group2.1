# %%
#Joey
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.linear_model import LinearRegression
from math import e
from random import sample
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
esg2016 = pd.read_csv('sp_500_esg_scores_2016.csv', index_col=0)
esg2017 = pd.read_csv('sp_500_esg_scores_2017.csv', index_col=0)
esg2018 = pd.read_csv('sp_500_esg_scores_2018.csv', index_col=0)
esg2019 = pd.read_csv('sp_500_esg_scores_2019.csv', index_col=0)
esg2020 = pd.read_csv('sp_500_esg_scores_2020.csv', index_col=0)
esg2021 = pd.read_csv('sp_500_esg_scores_2021.csv', index_col=0)
total_revenue = pd.read_csv('sp_500_total_revenue.csv', index_col=0)
county = pd.read_csv('sp_500_headquarters_country.csv', index_col=0)

# %%
esg2016 = pd.concat([esg2016, county['Country of Headquarters']], axis=1, join='inner')
esg2017 = pd.concat([esg2017, county['Country of Headquarters']], axis=1, join='inner')
esg2018 = pd.concat([esg2018, county['Country of Headquarters']], axis=1, join='inner')
esg2019 = pd.concat([esg2019, county['Country of Headquarters']], axis=1, join='inner')
esg2020 = pd.concat([esg2020, county['Country of Headquarters']], axis=1, join='inner')
esg2021 = pd.concat([esg2021, county['Country of Headquarters']], axis=1, join='inner')

# %%
combdf=pd.DataFrame()
combdf['Revenue'] = pd.concat([total_revenue['2016'],total_revenue['2017'],total_revenue['2018'],total_revenue['2019'],total_revenue['2020'],total_revenue['2021']],ignore_index=True)
combdf['Environmental'] = pd.concat([esg2016['Environmental Pillar Score'],esg2017['Environmental Pillar Score'],esg2018['Environmental Pillar Score'],esg2019['Environmental Pillar Score'],esg2020['Environmental Pillar Score'],esg2021['Environmental Pillar Score']],ignore_index=True)
combdf['Social'] = pd.concat([esg2016['Social Pillar Score'],esg2017['Social Pillar Score'],esg2018['Social Pillar Score'],esg2019['Social Pillar Score'],esg2020['Social Pillar Score'],esg2021['Social Pillar Score']],ignore_index=True)
combdf['Governance'] = pd.concat([esg2016['Governance Pillar Score'],esg2017['Governance Pillar Score'],esg2018['Governance Pillar Score'],esg2019['Governance Pillar Score'],esg2020['Governance Pillar Score'],esg2021['Governance Pillar Score']],ignore_index=True)
combdf=combdf.astype(float)
combdf['Country'] = pd.concat([esg2016['Country of Headquarters'],esg2017['Country of Headquarters'],esg2018['Country of Headquarters'],esg2019['Country of Headquarters'],esg2020['Country of Headquarters'],esg2021['Country of Headquarters']],ignore_index=True)
print(combdf)
# Out:
#         Revenue  Environmental     Social  Governance  \
# 0     30109.000      85.960218  95.147458   79.882889
# 1      2685.900      30.054673  31.722409   60.465017
# 2     20853.000      58.257135  85.968248   80.465921
# 3     25638.000      65.490633  88.756966   61.789019
# 4       445.304       0.000000  24.706148   25.957053
# ...         ...            ...        ...         ...
# 3013   6584.000      88.302439  87.524782   53.613973
# 3014   5627.000            NaN        NaN         NaN
# 3015   7836.200      42.206852  80.996962   63.015064
# 3016        NaN      41.078343  46.071616   64.295739
# 3017   7776.000      64.227996  76.768397   56.937934
#
#                        Country
# 0     United States of America
# 1     United States of America
# 2     United States of America
# 3     United States of America
# 4     United States of America
# ...                        ...
# 3013  United States of America
# 3014  United States of America
# 3015  United States of America
# 3016  United States of America
# 3017  United States of America
#
# [3018 rows x 5 columns]

# %%
#To remove rows with empty cells 
combdf.dropna(subset=['Revenue'], inplace=True)
combdf.dropna(subset=['Social'], inplace=True)
combdf
# Out:
#         Revenue  Environmental     Social  Governance  \
# 0     30109.000      85.960218  95.147458   79.882889
# 1      2685.900      30.054673  31.722409   60.465017
# 2     20853.000      58.257135  85.968248   80.465921
# 3     25638.000      65.490633  88.756966   61.789019
# 4       445.304       0.000000  24.706148   25.957053
# ...         ...            ...        ...         ...
# 3010   3763.664      75.047258  78.085744   71.039307
# 3012   5195.000      75.606710  84.010193   94.148284
# 3013   6584.000      88.302439  87.524782   53.613973
# 3015   7836.200      42.206852  80.996962   63.015064
# 3017   7776.000      64.227996  76.768397   56.937934
#
#                        Country
# 0     United States of America
# 1     United States of America
# 2     United States of America
# 3     United States of America
# 4     United States of America
# ...                        ...
# 3010  United States of America
# 3012  United States of America
# 3013  United States of America
# 3015  United States of America
# 3017  United States of America
#
# [2691 rows x 5 columns]

# %%
df_Ireland=combdf[ (combdf['Country'] == 'Ireland; Republic of') ]
df_UK=combdf[ (combdf['Country'] == 'United Kingdom') ]
df_US=combdf[ (combdf['Country'] == 'United States of America') ]

# %% [markdown]
# # Spliting data into train and test data

# %%
df_train, df_test = train_test_split(combdf , test_size=0.2, random_state=1)
df_Ireland_train, df_Ireland_test = train_test_split(df_Ireland , test_size=0.2, random_state=1)
df_UK_train, df_UK_test = train_test_split(df_UK , test_size=0.2, random_state=1)
df_US_train, df_US_test = train_test_split(df_US , test_size=0.2, random_state=1)

# %% [markdown]
# # Predictive model

# %%
model1 = smf.ols('Revenue ~ Environmental', data=df_train).fit()
print(model1.summary())

df_test['Revenue_pred'] = model1.predict(df_test)
df_test['SSD'] = (df_test['Revenue'] - df_test['Revenue_pred'])**2
SSD = df_test['SSD'].sum()
RSE = np.sqrt(SSD / 537)   # n = 539, p = 1
Revenuemean = np.mean(df_test['Revenue'])
error = RSE / Revenuemean

r1=0.064
f1=147.6
e1=error

print(f'Error = {np.round(error, 4)*100}%')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                  0.064
# Method:                 Least Squares   F-statistic:                     147.6
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):           6.83e-33
# Time:                        16:31:18   Log-Likelihood:                -26156.
# No. Observations:                2152   AIC:                         5.232e+04
# Df Residuals:                    2150   BIC:                         5.233e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      -772.5631   2267.730     -0.341      0.733   -5219.737    3674.610
# Environmental   459.2224     37.802     12.148      0.000     385.091     533.354
# ==============================================================================
# Omnibus:                     2352.818   Durbin-Watson:                   1.964
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           179954.685
# Skew:                           5.498   Prob(JB):                         0.00
# Kurtosis:                      46.428   Cond. No.                         137.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 185.60000000000002%

# %%
model2 = smf.ols('Revenue ~ Social', data=df_train).fit()
print(model2.summary())

df_test['Revenue_pred'] = model2.predict(df_test)
df_test['SSD'] = (df_test['Revenue'] - df_test['Revenue_pred'])**2
SSD = df_test['SSD'].sum()
RSE = np.sqrt(SSD / 537)   # n = 539, p = 1
Revenuemean = np.mean(df_test['Revenue'])
error = RSE / Revenuemean

r2=0.037
f2=83.49
e2=error

print(f'Error = {np.round(error, 4)*100}%')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     83.49
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):           1.44e-19
# Time:                        16:31:21   Log-Likelihood:                -26187.
# No. Observations:                2152   AIC:                         5.238e+04
# Df Residuals:                    2150   BIC:                         5.239e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -6354.9308   3471.376     -1.831      0.067   -1.32e+04     452.674
# Social       474.4690     51.926      9.137      0.000     372.639     576.299
# ==============================================================================
# Omnibus:                     2359.502   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           177362.079
# Skew:                           5.535   Prob(JB):                         0.00
# Kurtosis:                      46.075   Cond. No.                         231.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 189.01%

# %%
model3 = smf.ols('Revenue ~ Governance', data=df_train).fit()
print(model3.summary())

df_test['Revenue_pred'] = model3.predict(df_test)
df_test['SSD'] = (df_test['Revenue'] - df_test['Revenue_pred'])**2
SSD = df_test['SSD'].sum()
RSE = np.sqrt(SSD / 537)   # n = 539, p = 1
Revenuemean = np.mean(df_test['Revenue'])
error = RSE / Revenuemean

r3=0.023
f3=49.83
e3=error

print(f'Error = {np.round(error, 4)*100}%')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     49.83
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):           2.26e-12
# Time:                        16:31:22   Log-Likelihood:                -26203.
# No. Observations:                2152   AIC:                         5.241e+04
# Df Residuals:                    2150   BIC:                         5.242e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    455.6796   3486.656      0.131      0.896   -6381.890    7293.249
# Governance   376.9439     53.401      7.059      0.000     272.220     481.668
# ==============================================================================
# Omnibus:                     2327.478   Durbin-Watson:                   1.959
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           166721.023
# Skew:                           5.423   Prob(JB):                         0.00
# Kurtosis:                      44.734   Cond. No.                         225.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 191.13%

# %%
model4 = smf.ols('Revenue ~ Environmental+Social', data=df_train).fit()
print(model4.summary())

df_test['Revenue_pred'] = model4.predict(df_test)
df_test['SSD'] = (df_test['Revenue'] - df_test['Revenue_pred'])**2
SSD = df_test['SSD'].sum()
RSE = np.sqrt(SSD / 536)   # n = 539, p = 2
Revenuemean = np.mean(df_test['Revenue'])
error = RSE / Revenuemean


r4=0.065
f4=74.57
e4=error

print(f'Error = {np.round(error, 4)*100}%')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.065
# Model:                            OLS   Adj. R-squared:                  0.064
# Method:                 Least Squares   F-statistic:                     74.57
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):           4.88e-32
# Time:                        16:31:22   Log-Likelihood:                -26156.
# No. Observations:                2152   AIC:                         5.232e+04
# Df Residuals:                    2149   BIC:                         5.233e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -3962.0896   3435.405     -1.153      0.249   -1.07e+04    2774.976
# Environmental   414.7942     52.163      7.952      0.000     312.499     517.089
# Social           87.3089     70.647      1.236      0.217     -51.234     225.852
# ==============================================================================
# Omnibus:                     2355.413   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           180436.792
# Skew:                           5.508   Prob(JB):                         0.00
# Kurtosis:                      46.485   Cond. No.                         307.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 185.84%

# %%
model5 = smf.ols('Revenue ~ Environmental+Governance', data=df_train).fit()
print(model5.summary())

df_test['Revenue_pred'] = model5.predict(df_test)
df_test['SSD'] = (df_test['Revenue'] - df_test['Revenue_pred'])**2
SSD = df_test['SSD'].sum()
RSE = np.sqrt(SSD / 536)   # n = 539, p = 2
Revenuemean = np.mean(df_test['Revenue'])
error = RSE / Revenuemean


r5=0.070
f5=80.29
e5=error

print(f'Error = {np.round(error, 4)*100}%')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     80.29
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):           2.36e-34
# Time:                        16:31:23   Log-Likelihood:                -26150.
# No. Observations:                2152   AIC:                         5.231e+04
# Df Residuals:                    2149   BIC:                         5.232e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -1.038e+04   3558.535     -2.916      0.004   -1.74e+04   -3399.312
# Environmental   414.3789     39.825     10.405      0.000     336.279     492.479
# Governance      192.4745     55.050      3.496      0.000      84.517     300.432
# ==============================================================================
# Omnibus:                     2344.165   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           177184.422
# Skew:                           5.467   Prob(JB):                         0.00
# Kurtosis:                      46.087   Cond. No.                         311.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 185.78%

# %%
model6 = smf.ols('Revenue ~ Social+Governance', data=df_train).fit()
print(model6.summary())

df_test['Revenue_pred'] = model6.predict(df_test)
df_test['SSD'] = (df_test['Revenue'] - df_test['Revenue_pred'])**2
SSD = df_test['SSD'].sum()
RSE = np.sqrt(SSD / 536)   # n = 539, p = 2
Revenuemean = np.mean(df_test['Revenue'])
error = RSE / Revenuemean

r6=0.048
f6=54.20
e6=error

print(f'Error = {np.round(error, 4)*100}%')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     54.20
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):           1.08e-23
# Time:                        16:31:23   Log-Likelihood:                -26175.
# No. Observations:                2152   AIC:                         5.236e+04
# Df Residuals:                    2149   BIC:                         5.237e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.866e+04   4269.228     -4.371      0.000    -2.7e+04   -1.03e+04
# Social       405.2536     53.546      7.568      0.000     300.247     510.260
# Governance   267.8584     54.651      4.901      0.000     160.684     375.032
# ==============================================================================
# Omnibus:                     2347.771   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           174093.211
# Skew:                           5.492   Prob(JB):                         0.00
# Kurtosis:                      45.672   Cond. No.                         393.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 188.88%

# %%
model7 = smf.ols('Revenue ~ Environmental+Social+Governance', data=df_train).fit()
print(model7.summary())

df_test['Revenue_pred'] = model7.predict(df_test)
df_test['SSD'] = (df_test['Revenue'] - df_test['Revenue_pred'])**2
SSD = df_test['SSD'].sum()
RSE = np.sqrt(SSD / 535)   # n = 539, p = 3
Revenuemean = np.mean(df_test['Revenue'])
error = RSE / Revenuemean

r7=0.070
f7=53.88
e7=error

print(f'Error = {np.round(error, 4)*100}%')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     53.88
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):           1.42e-33
# Time:                        16:31:24   Log-Likelihood:                -26150.
# No. Observations:                2152   AIC:                         5.231e+04
# Df Residuals:                    2148   BIC:                         5.233e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -1.286e+04   4298.646     -2.991      0.003   -2.13e+04   -4426.664
# Environmental   378.2554     53.114      7.122      0.000     274.095     482.416
# Social           72.5698     70.602      1.028      0.304     -65.885     211.025
# Governance      189.0214     55.152      3.427      0.001      80.865     297.178
# ==============================================================================
# Omnibus:                     2346.664   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           177668.612
# Skew:                           5.477   Prob(JB):                         0.00
# Kurtosis:                      46.144   Cond. No.                         472.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 186.01000000000002%

# %%
summary=pd.DataFrame()
summary['Adjusted R']=(r1,r2,r3,r4,r5,r6,r7)
summary['Error']=(e1,e2,e3,e4,e5,e6,e7)
summary['F-statistic']=(f1,f2,f3,f4,f5,f6,f7)
summary
# Out:
#    Adjusted R     Error  F-statistic
# 0       0.064  1.856042       147.60
# 1       0.037  1.890123        83.49
# 2       0.023  1.911290        49.83
# 3       0.065  1.858370        74.57
# 4       0.070  1.857787        80.29
# 5       0.048  1.888809        54.20
# 6       0.070  1.860133        53.88

# %% [markdown]
# By compairing Adujusted R-square, Error and F-statistic of each model, the 5th model is the best choice.
#
# The best prediction model is: Revenue = -10380 + 414.3789 * Environmental Pillar Score + 192.4745 * Governance Pillar Score

# %% [markdown]
# # Ireland

# %%
model1 = smf.ols('Revenue ~ Environmental', data=df_Ireland_train).fit()
print(model1.summary())

df_Ireland_test['Revenue_pred'] = model1.predict(df_Ireland_test)
df_Ireland_test['SSD'] = (df_Ireland_test['Revenue'] - df_Ireland_test['Revenue_pred'])**2
SSD = df_Ireland_test['SSD'].sum()
RSE = np.sqrt(SSD / 10)   # n = 12, p = 1
Revenuemean = np.mean(df_Ireland_test['Revenue'])
error = RSE / Revenuemean

r1=0.453
f1=36.55
e1=error

print(f'Error = {np.round(error, 4)*100}%')

model2 = smf.ols('Revenue ~ Social', data=df_Ireland_train).fit()
print(model2.summary())

df_Ireland_test['Revenue_pred'] = model2.predict(df_Ireland_test)
df_Ireland_test['SSD'] = (df_Ireland_test['Revenue'] - df_Ireland_test['Revenue_pred'])**2
SSD = df_Ireland_test['SSD'].sum()
RSE = np.sqrt(SSD / 10)   # n = 12, p = 1
Revenuemean = np.mean(df_Ireland_test['Revenue'])
error = RSE / Revenuemean

r2=0.305
f2=19.90
e2=error

print(f'Error = {np.round(error, 4)*100}%')

model3 = smf.ols('Revenue ~ Governance', data=df_Ireland_train).fit()
print(model3.summary())

df_Ireland_test['Revenue_pred'] = model3.predict(df_Ireland_test)
df_Ireland_test['SSD'] = (df_Ireland_test['Revenue'] - df_Ireland_test['Revenue_pred'])**2
SSD = df_Ireland_test['SSD'].sum()
RSE = np.sqrt(SSD / 10)   # n = 12, p = 1
Revenuemean = np.mean(df_Ireland_test['Revenue'])
error = RSE / Revenuemean

r3=0.056
f3=3.574
e3=error

print(f'Error = {np.round(error, 4)*100}%')

model4 = smf.ols('Revenue ~ Environmental+Social', data=df_Ireland_train).fit()
print(model4.summary())

df_Ireland_test['Revenue_pred'] = model4.predict(df_Ireland_test)
df_Ireland_test['SSD'] = (df_Ireland_test['Revenue'] - df_Ireland_test['Revenue_pred'])**2
SSD = df_Ireland_test['SSD'].sum()
RSE = np.sqrt(SSD / 9)   # n = 12, p = 2
Revenuemean = np.mean(df_Ireland_test['Revenue'])
error = RSE / Revenuemean


r4=0.440
f4=17.86
e4=error

print(f'Error = {np.round(error, 4)*100}%')

model5 = smf.ols('Revenue ~ Environmental+Governance', data=df_Ireland_train).fit()
print(model5.summary())

df_Ireland_test['Revenue_pred'] = model5.predict(df_Ireland_test)
df_Ireland_test['SSD'] = (df_Ireland_test['Revenue'] - df_Ireland_test['Revenue_pred'])**2
SSD = df_Ireland_test['SSD'].sum()
RSE = np.sqrt(SSD / 9)   # n = 12, p = 2
Revenuemean = np.mean(df_Ireland_test['Revenue'])
error = RSE / Revenuemean


r5=0.517
f5=23.99
e5=error

print(f'Error = {np.round(error, 4)*100}%')

model6 = smf.ols('Revenue ~ Social+Governance', data=df_Ireland_train).fit()
print(model6.summary())

df_Ireland_test['Revenue_pred'] = model6.predict(df_Ireland_test)
df_Ireland_test['SSD'] = (df_Ireland_test['Revenue'] - df_Ireland_test['Revenue_pred'])**2
SSD = df_Ireland_test['SSD'].sum()
RSE = np.sqrt(SSD / 9)   # n = 12, p = 2
Revenuemean = np.mean(df_Ireland_test['Revenue'])
error = RSE / Revenuemean

r6=0.336
f6=11.87
e6=error

print(f'Error = {np.round(error, 4)*100}%')

model7 = smf.ols('Revenue ~ Environmental+Social+Governance', data=df_Ireland_train).fit()
print(model7.summary())

df_Ireland_test['Revenue_pred'] = model7.predict(df_Ireland_test)
df_Ireland_test['SSD'] = (df_Ireland_test['Revenue'] - df_Ireland_test['Revenue_pred'])**2
SSD = df_Ireland_test['SSD'].sum()
RSE = np.sqrt(SSD / 8)   # n = 12,, p = 3
Revenuemean = np.mean(df_Ireland_test['Revenue'])
error = RSE / Revenuemean

r7=0.506
f7=15.69
e7=error

print(f'Error = {np.round(error, 4)*100}%')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.465
# Model:                            OLS   Adj. R-squared:                  0.453
# Method:                 Least Squares   F-statistic:                     36.55
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):           3.41e-07
# Time:                        16:31:40   Log-Likelihood:                -460.91
# No. Observations:                  44   AIC:                             925.8
# Df Residuals:                      42   BIC:                             929.4
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -3104.5951   3839.797     -0.809      0.423   -1.09e+04    4644.429
# Environmental   350.9392     58.045      6.046      0.000     233.800     468.079
# ==============================================================================
# Omnibus:                       13.044   Durbin-Watson:                   1.739
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               13.413
# Skew:                           1.250   Prob(JB):                      0.00122
# Kurtosis:                       4.032   Cond. No.                         192.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 101.14000000000001%
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.322
# Model:                            OLS   Adj. R-squared:                  0.305
# Method:                 Least Squares   F-statistic:                     19.90
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):           5.99e-05
# Time:                        16:31:40   Log-Likelihood:                -466.15
# No. Observations:                  44   AIC:                             936.3
# Df Residuals:                      42   BIC:                             939.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.384e+04   7443.048     -1.860      0.070   -2.89e+04    1176.475
# Social       431.5569     96.731      4.461      0.000     236.345     626.769
# ==============================================================================
# Omnibus:                       14.106   Durbin-Watson:                   2.062
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.346
# Skew:                           1.196   Prob(JB):                     0.000465
# Kurtosis:                       4.627   Cond. No.                         384.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 108.05%
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.078
# Model:                            OLS   Adj. R-squared:                  0.056
# Method:                 Least Squares   F-statistic:                     3.574
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):             0.0656
# Time:                        16:31:40   Log-Likelihood:                -472.88
# No. Observations:                  44   AIC:                             949.8
# Df Residuals:                      42   BIC:                             953.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   8707.5610   5558.220      1.567      0.125   -2509.381    1.99e+04
# Governance   181.0373     95.756      1.891      0.066     -12.205     374.280
# ==============================================================================
# Omnibus:                        4.595   Durbin-Watson:                   2.407
# Prob(Omnibus):                  0.100   Jarque-Bera (JB):                3.957
# Skew:                           0.642   Prob(JB):                        0.138
# Kurtosis:                       2.285   Cond. No.                         186.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 105.67%
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.466
# Model:                            OLS   Adj. R-squared:                  0.440
# Method:                 Least Squares   F-statistic:                     17.86
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):           2.64e-06
# Time:                        16:31:40   Log-Likelihood:                -460.89
# No. Observations:                  44   AIC:                             927.8
# Df Residuals:                      41   BIC:                             933.1
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -4024.5087   7308.873     -0.551      0.585   -1.88e+04    1.07e+04
# Environmental   338.5783    101.829      3.325      0.002     132.931     544.225
# Social           22.3851    150.643      0.149      0.883    -281.844     326.614
# ==============================================================================
# Omnibus:                       13.301   Durbin-Watson:                   1.751
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               13.773
# Skew:                           1.258   Prob(JB):                      0.00102
# Kurtosis:                       4.087   Cond. No.                         551.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 106.54999999999998%
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.539
# Model:                            OLS   Adj. R-squared:                  0.517
# Method:                 Least Squares   F-statistic:                     23.99
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):           1.26e-07
# Time:                        16:31:40   Log-Likelihood:                -457.63
# No. Observations:                  44   AIC:                             921.3
# Df Residuals:                      41   BIC:                             926.6
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -1.269e+04   5195.157     -2.443      0.019   -2.32e+04   -2198.981
# Environmental   349.2537     54.541      6.403      0.000     239.105     459.402
# Governance      175.7489     68.533      2.564      0.014      37.343     314.155
# ==============================================================================
# Omnibus:                        4.118   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.128   Jarque-Bera (JB):                3.409
# Skew:                           0.681   Prob(JB):                        0.182
# Kurtosis:                       3.082   Cond. No.                         358.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 96.52%
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.367
# Model:                            OLS   Adj. R-squared:                  0.336
# Method:                 Least Squares   F-statistic:                     11.87
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):           8.56e-05
# Time:                        16:31:40   Log-Likelihood:                -464.63
# No. Observations:                  44   AIC:                             935.3
# Df Residuals:                      41   BIC:                             940.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.998e+04   8114.680     -2.463      0.018   -3.64e+04   -3596.365
# Social       411.7158     95.294      4.320      0.000     219.266     604.166
# Governance   138.4802     80.940      1.711      0.095     -24.981     301.942
# ==============================================================================
# Omnibus:                        6.422   Durbin-Watson:                   2.267
# Prob(Omnibus):                  0.040   Jarque-Bera (JB):                5.175
# Skew:                           0.757   Prob(JB):                       0.0752
# Kurtosis:                       3.730   Cond. No.                         529.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 103.32%
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.541
# Model:                            OLS   Adj. R-squared:                  0.506
# Method:                 Least Squares   F-statistic:                     15.69
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):           6.77e-07
# Time:                        16:31:40   Log-Likelihood:                -457.57
# No. Observations:                  44   AIC:                             923.1
# Df Residuals:                      40   BIC:                             930.3
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -1.093e+04   7374.556     -1.482      0.146   -2.58e+04    3974.428
# Environmental   376.2820     96.724      3.890      0.000     180.795     571.769
# Social          -49.0282    144.152     -0.340      0.736    -340.371     242.314
# Governance      180.4075     70.625      2.554      0.015      37.668     323.147
# ==============================================================================
# Omnibus:                        3.835   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.147   Jarque-Bera (JB):                3.288
# Skew:                           0.669   Prob(JB):                        0.193
# Kurtosis:                       2.965   Cond. No.                         674.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 102.91%

# %%
summary=pd.DataFrame()
summary['Adjusted R']=(r1,r2,r3,r4,r5,r6,r7)
summary['Error']=(e1,e2,e3,e4,e5,e6,e7)
summary['F-statistic']=(f1,f2,f3,f4,f5,f6,f7)
summary
# Out:
#    Adjusted R     Error  F-statistic
# 0       0.453  1.011411       36.550
# 1       0.305  1.080516       19.900
# 2       0.056  1.056739        3.574
# 3       0.440  1.065517       17.860
# 4       0.517  0.965195       23.990
# 5       0.336  1.033184       11.870
# 6       0.506  1.029103       15.690

# %% [markdown]
# By compairing Adujusted R-square, Error and F-statistic of each model, the 5th model is the best choice.
#
# The best prediction model for Ireland is: Revenue = -12690 + 349.2537 * Environmental Pillar Score + 175.7489 * Governance Pillar Score

# %% [markdown]
# # United Kingdom

# %%
model1 = smf.ols('Revenue ~ Environmental', data=df_UK_train).fit()
print(model1.summary())

df_UK_test['Revenue_pred'] = model1.predict(df_UK_test)
df_UK_test['SSD'] = (df_UK_test['Revenue'] - df_UK_test['Revenue_pred'])**2
SSD = df_UK_test['SSD'].sum()
RSE = np.sqrt(SSD / 4)   # n = 6, p = 1
Revenuemean = np.mean(df_UK_test['Revenue'])
error = RSE / Revenuemean

r1=0.018
f1=1.419
e1=error

print(f'Error = {np.round(error, 4)*100}%')

model2 = smf.ols('Revenue ~ Social', data=df_UK_train).fit()
print(model2.summary())

df_UK_test['Revenue_pred'] = model2.predict(df_UK_test)
df_UK_test['SSD'] = (df_UK_test['Revenue'] - df_UK_test['Revenue_pred'])**2
SSD = df_UK_test['SSD'].sum()
RSE = np.sqrt(SSD / 4)   # n = 6, p = 1
Revenuemean = np.mean(df_UK_test['Revenue'])
error = RSE / Revenuemean

r2=-0.014
f2=0.6760
e2=error

print(f'Error = {np.round(error, 4)*100}%')

model3 = smf.ols('Revenue ~ Governance', data=df_UK_train).fit()
print(model3.summary())

df_UK_test['Revenue_pred'] = model3.predict(df_UK_test)
df_UK_test['SSD'] = (df_UK_test['Revenue'] - df_UK_test['Revenue_pred'])**2
SSD = df_UK_test['SSD'].sum()
RSE = np.sqrt(SSD / 4)   # n = 6, p = 1
Revenuemean = np.mean(df_UK_test['Revenue'])
error = RSE / Revenuemean

r3=0.305
f3=11.08
e3=error

print(f'Error = {np.round(error, 4)*100}%')

model4 = smf.ols('Revenue ~ Environmental+Social', data=df_UK_train).fit()
print(model4.summary())

df_UK_test['Revenue_pred'] = model4.predict(df_UK_test)
df_UK_test['SSD'] = (df_UK_test['Revenue'] - df_UK_test['Revenue_pred'])**2
SSD = df_UK_test['SSD'].sum()
RSE = np.sqrt(SSD / 3)   # n = 6, p = 2
Revenuemean = np.mean(df_UK_test['Revenue'])
error = RSE / Revenuemean


r4=-0.021
f4=0.7689
e4=error

print(f'Error = {np.round(error, 4)*100}%')

model5 = smf.ols('Revenue ~ Environmental+Governance', data=df_UK_train).fit()
print(model5.summary())

df_UK_test['Revenue_pred'] = model5.predict(df_UK_test)
df_UK_test['SSD'] = (df_UK_test['Revenue'] - df_UK_test['Revenue_pred'])**2
SSD = df_UK_test['SSD'].sum()
RSE = np.sqrt(SSD / 3)   # n = 6, p = 2
Revenuemean = np.mean(df_UK_test['Revenue'])
error = RSE / Revenuemean


r5=0.363
f5=7.548
e5=error

print(f'Error = {np.round(error, 4)*100}%')

model6 = smf.ols('Revenue ~ Social+Governance', data=df_UK_train).fit()
print(model6.summary())

df_UK_test['Revenue_pred'] = model6.predict(df_UK_test)
df_UK_test['SSD'] = (df_UK_test['Revenue'] - df_UK_test['Revenue_pred'])**2
SSD = df_UK_test['SSD'].sum()
RSE = np.sqrt(SSD / 3)   # n = 6, p = 2
Revenuemean = np.mean(df_UK_test['Revenue'])
error = RSE / Revenuemean

r6=0.325
f6=6.545
e6=error

print(f'Error = {np.round(error, 4)*100}%')

model7 = smf.ols('Revenue ~ Environmental+Social+Governance', data=df_UK_train).fit()
print(model7.summary())

df_UK_test['Revenue_pred'] = model7.predict(df_UK_test)
df_UK_test['SSD'] = (df_UK_test['Revenue'] - df_UK_test['Revenue_pred'])**2
SSD = df_UK_test['SSD'].sum()
RSE = np.sqrt(SSD / 2)   # n = 6,, p = 3
Revenuemean = np.mean(df_UK_test['Revenue'])
error = RSE / Revenuemean

r7=0.335
f7=4.870
e7=error

print(f'Error = {np.round(error, 4)*100}%')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.061
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     1.419
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):              0.246
# Time:                        16:31:44   Log-Likelihood:                -260.02
# No. Observations:                  24   AIC:                             524.0
# Df Residuals:                      22   BIC:                             526.4
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      6146.2871   8203.710      0.749      0.462   -1.09e+04    2.32e+04
# Environmental   148.0410    124.269      1.191      0.246    -109.677     405.759
# ==============================================================================
# Omnibus:                        4.058   Durbin-Watson:                   2.182
# Prob(Omnibus):                  0.131   Jarque-Bera (JB):                3.426
# Skew:                           0.907   Prob(JB):                        0.180
# Kurtosis:                       2.636   Cond. No.                         207.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 69.36%
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.030
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.6760
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):              0.420
# Time:                        16:31:44   Log-Likelihood:                -260.41
# No. Observations:                  24   AIC:                             524.8
# Df Residuals:                      22   BIC:                             527.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   6665.9425    1.1e+04      0.608      0.549   -1.61e+04    2.94e+04
# Social       129.5601    157.574      0.822      0.420    -197.229     456.349
# ==============================================================================
# Omnibus:                        4.794   Durbin-Watson:                   2.129
# Prob(Omnibus):                  0.091   Jarque-Bera (JB):                4.098
# Skew:                           0.999   Prob(JB):                        0.129
# Kurtosis:                       2.678   Cond. No.                         287.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 74.14%
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.335
# Model:                            OLS   Adj. R-squared:                  0.305
# Method:                 Least Squares   F-statistic:                     11.08
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):            0.00305
# Time:                        16:31:44   Log-Likelihood:                -255.88
# No. Observations:                  24   AIC:                             515.8
# Df Residuals:                      22   BIC:                             518.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -3188.6513   6005.729     -0.531      0.601   -1.56e+04    9266.469
# Governance   300.1419     90.176      3.328      0.003     113.127     487.156
# ==============================================================================
# Omnibus:                        2.189   Durbin-Watson:                   1.531
# Prob(Omnibus):                  0.335   Jarque-Bera (JB):                1.887
# Skew:                           0.600   Prob(JB):                        0.389
# Kurtosis:                       2.330   Cond. No.                         182.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 89.08%
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.068
# Model:                            OLS   Adj. R-squared:                 -0.021
# Method:                 Least Squares   F-statistic:                    0.7689
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):              0.476
# Time:                        16:31:44   Log-Likelihood:                -259.92
# No. Observations:                  24   AIC:                             525.8
# Df Residuals:                      21   BIC:                             529.4
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      9336.4800   1.14e+04      0.822      0.420   -1.43e+04     3.3e+04
# Environmental   242.4804    260.592      0.930      0.363    -299.450     784.411
# Social         -134.8378    325.148     -0.415      0.683    -811.020     541.344
# ==============================================================================
# Omnibus:                        3.347   Durbin-Watson:                   2.168
# Prob(Omnibus):                  0.188   Jarque-Bera (JB):                2.789
# Skew:                           0.813   Prob(JB):                        0.248
# Kurtosis:                       2.619   Cond. No.                         407.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 76.36%
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.418
# Model:                            OLS   Adj. R-squared:                  0.363
# Method:                 Least Squares   F-statistic:                     7.548
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):            0.00339
# Time:                        16:31:44   Log-Likelihood:                -254.27
# No. Observations:                  24   AIC:                             514.5
# Df Residuals:                      21   BIC:                             518.1
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -1.475e+04   8802.521     -1.675      0.109   -3.31e+04    3557.691
# Environmental   174.0372    100.357      1.734      0.098     -34.667     382.741
# Governance      310.9630     86.549      3.593      0.002     130.974     490.952
# ==============================================================================
# Omnibus:                        1.504   Durbin-Watson:                   1.662
# Prob(Omnibus):                  0.471   Jarque-Bera (JB):                1.294
# Skew:                           0.524   Prob(JB):                        0.524
# Kurtosis:                       2.559   Cond. No.                         379.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 93.82000000000001%
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.384
# Model:                            OLS   Adj. R-squared:                  0.325
# Method:                 Least Squares   F-statistic:                     6.545
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):            0.00618
# Time:                        16:31:44   Log-Likelihood:                -254.96
# No. Observations:                  24   AIC:                             515.9
# Df Residuals:                      21   BIC:                             519.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.504e+04   1.09e+04     -1.379      0.182   -3.77e+04    7642.854
# Social       166.7766    128.962      1.293      0.210    -101.416     434.969
# Governance   309.7159     89.137      3.475      0.002     124.345     495.087
# ==============================================================================
# Omnibus:                        2.030   Durbin-Watson:                   1.656
# Prob(Omnibus):                  0.362   Jarque-Bera (JB):                1.671
# Skew:                           0.617   Prob(JB):                        0.434
# Kurtosis:                       2.616   Cond. No.                         471.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 99.88%
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.422
# Model:                            OLS   Adj. R-squared:                  0.335
# Method:                 Least Squares   F-statistic:                     4.870
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):             0.0106
# Time:                        16:31:44   Log-Likelihood:                -254.19
# No. Observations:                  24   AIC:                             516.4
# Df Residuals:                      20   BIC:                             521.1
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -1.237e+04   1.11e+04     -1.117      0.277   -3.55e+04    1.07e+04
# Environmental   241.7434    210.285      1.150      0.264    -196.903     680.390
# Social          -96.8299    262.603     -0.369      0.716    -644.610     450.950
# Governance      309.6141     88.462      3.500      0.002     125.085     494.143
# ==============================================================================
# Omnibus:                        1.257   Durbin-Watson:                   1.650
# Prob(Omnibus):                  0.533   Jarque-Bera (JB):                1.141
# Skew:                           0.470   Prob(JB):                        0.565
# Kurtosis:                       2.493   Cond. No.                         584.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 112.08%

# %%
summary=pd.DataFrame()
summary['Adjusted R']=(r1,r2,r3,r4,r5,r6,r7)
summary['Error']=(e1,e2,e3,e4,e5,e6,e7)
summary['F-statistic']=(f1,f2,f3,f4,f5,f6,f7)
summary
# Out:
#    Adjusted R     Error  F-statistic
# 0       0.018  0.693597       1.4190
# 1      -0.014  0.741401       0.6760
# 2       0.305  0.890813      11.0800
# 3      -0.021  0.763633       0.7689
# 4       0.363  0.938249       7.5480
# 5       0.325  0.998778       6.5450
# 6       0.335  1.120773       4.8700

# %% [markdown]
# By compairing Adujusted R-square, Error and F-statistic of each model, the 5th model is the best choice.
#
# The best prediction model for UK is: Revenue = -14750 + 174.0372 * Environmental Pillar Score + 310.9630 * Governance Pillar Score

# %% [markdown]
# # United States of America

# %%
model1 = smf.ols('Revenue ~ Environmental', data=df_US_train).fit()
print(model1.summary())

df_US_test['Revenue_pred'] = model1.predict(df_US_test)
df_US_test['SSD'] = (df_US_test['Revenue'] - df_US_test['Revenue_pred'])**2
SSD = df_US_test['SSD'].sum()
RSE = np.sqrt(SSD / 512)   # n = 514, p = 1
Revenuemean = np.mean(df_US_test['Revenue'])
error = RSE / Revenuemean

r1=0.072
f1=161.3
e1=error

print(f'Error = {np.round(error, 4)*100}%')

model2 = smf.ols('Revenue ~ Social', data=df_US_train).fit()
print(model2.summary())

df_US_test['Revenue_pred'] = model2.predict(df_US_test)
df_US_test['SSD'] = (df_US_test['Revenue'] - df_US_test['Revenue_pred'])**2
SSD = df_US_test['SSD'].sum()
RSE = np.sqrt(SSD / 512)   # n = 514, p = 1
Revenuemean = np.mean(df_US_test['Revenue'])
error = RSE / Revenuemean

r2=0.043
f2=92.40
e2=error

print(f'Error = {np.round(error, 4)*100}%')

model3 = smf.ols('Revenue ~ Governance', data=df_US_train).fit()
print(model3.summary())

df_US_test['Revenue_pred'] = model3.predict(df_US_test)
df_US_test['SSD'] = (df_US_test['Revenue'] - df_US_test['Revenue_pred'])**2
SSD = df_US_test['SSD'].sum()
RSE = np.sqrt(SSD / 512)   # n = 514, p = 1
Revenuemean = np.mean(df_US_test['Revenue'])
error = RSE / Revenuemean

r3=0.020
f3=43.51
e3=error

print(f'Error = {np.round(error, 4)*100}%')

model4 = smf.ols('Revenue ~ Environmental+Social', data=df_US_train).fit()
print(model4.summary())

df_US_test['Revenue_pred'] = model4.predict(df_US_test)
df_US_test['SSD'] = (df_US_test['Revenue'] - df_US_test['Revenue_pred'])**2
SSD = df_US_test['SSD'].sum()
RSE = np.sqrt(SSD / 511)   # n = 514, p = 2
Revenuemean = np.mean(df_US_test['Revenue'])
error = RSE / Revenuemean


r4=0.073
f4=81.63
e4=error

print(f'Error = {np.round(error, 4)*100}%')

model5 = smf.ols('Revenue ~ Environmental+Governance', data=df_US_train).fit()
print(model5.summary())

df_US_test['Revenue_pred'] = model5.predict(df_US_test)
df_US_test['SSD'] = (df_US_test['Revenue'] - df_US_test['Revenue_pred'])**2
SSD = df_US_test['SSD'].sum()
RSE = np.sqrt(SSD / 511)   # n = 514, p = 2
Revenuemean = np.mean(df_US_test['Revenue'])
error = RSE / Revenuemean


r5=0.075
f5=84.52
e5=error

print(f'Error = {np.round(error, 4)*100}%')

model6 = smf.ols('Revenue ~ Social+Governance', data=df_US_train).fit()
print(model6.summary())

df_US_test['Revenue_pred'] = model6.predict(df_US_test)
df_US_test['SSD'] = (df_US_test['Revenue'] - df_US_test['Revenue_pred'])**2
SSD = df_US_test['SSD'].sum()
RSE = np.sqrt(SSD / 511)   # n = 514, p = 2
Revenuemean = np.mean(df_US_test['Revenue'])
error = RSE / Revenuemean

r6=0.050
f6=55.07
e6=error

print(f'Error = {np.round(error, 4)*100}%')

model7 = smf.ols('Revenue ~ Environmental+Social+Governance', data=df_US_train).fit()
print(model7.summary())

df_US_test['Revenue_pred'] = model7.predict(df_US_test)
df_US_test['SSD'] = (df_US_test['Revenue'] - df_US_test['Revenue_pred'])**2
SSD = df_US_test['SSD'].sum()
RSE = np.sqrt(SSD / 510)   # n = 514,, p = 3
Revenuemean = np.mean(df_US_test['Revenue'])
error = RSE / Revenuemean

r7=0.075
f7=56.81
e7=error

print(f'Error = {np.round(error, 4)*100}%')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.073
# Model:                            OLS   Adj. R-squared:                  0.072
# Method:                 Least Squares   F-statistic:                     161.3
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):           1.24e-35
# Time:                        16:31:47   Log-Likelihood:                -25094.
# No. Observations:                2054   AIC:                         5.019e+04
# Df Residuals:                    2052   BIC:                         5.020e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -2667.0947   2465.438     -1.082      0.279   -7502.116    2167.927
# Environmental   520.1030     40.950     12.701      0.000     439.795     600.411
# ==============================================================================
# Omnibus:                     2106.837   Durbin-Watson:                   1.944
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           120636.616
# Skew:                           5.030   Prob(JB):                         0.00
# Kurtosis:                      39.171   Cond. No.                         137.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 183.42000000000002%
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.043
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     92.40
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):           1.99e-21
# Time:                        16:31:47   Log-Likelihood:                -25127.
# No. Observations:                2054   AIC:                         5.026e+04
# Df Residuals:                    2052   BIC:                         5.027e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -9546.9803   3805.587     -2.509      0.012    -1.7e+04   -2083.764
# Social       547.1469     56.920      9.613      0.000     435.520     658.774
# ==============================================================================
# Omnibus:                     2112.902   Durbin-Watson:                   1.941
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           118578.744
# Skew:                           5.065   Prob(JB):                         0.00
# Kurtosis:                      38.818   Cond. No.                         232.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 185.07%
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     43.51
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):           5.34e-11
# Time:                        16:31:47   Log-Likelihood:                -25150.
# No. Observations:                2054   AIC:                         5.030e+04
# Df Residuals:                    2052   BIC:                         5.032e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1234.4764   3839.536      0.322      0.748   -6295.317    8764.270
# Governance   386.0124     58.518      6.597      0.000     271.252     500.772
# ==============================================================================
# Omnibus:                     2079.740   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           109249.181
# Skew:                           4.958   Prob(JB):                         0.00
# Kurtosis:                      37.325   Cond. No.                         227.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 183.73%
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.074
# Model:                            OLS   Adj. R-squared:                  0.073
# Method:                 Least Squares   F-statistic:                     81.63
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):           7.72e-35
# Time:                        16:31:47   Log-Likelihood:                -25093.
# No. Observations:                2054   AIC:                         5.019e+04
# Df Residuals:                    2051   BIC:                         5.021e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -6569.9800   3762.464     -1.746      0.081   -1.39e+04     808.669
# Environmental   466.4047     56.620      8.237      0.000     355.366     577.443
# Social          106.3607     77.466      1.373      0.170     -45.560     258.281
# ==============================================================================
# Omnibus:                     2109.084   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           120974.315
# Skew:                           5.039   Prob(JB):                         0.00
# Kurtosis:                      39.221   Cond. No.                         309.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 183.68%
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.076
# Model:                            OLS   Adj. R-squared:                  0.075
# Method:                 Least Squares   F-statistic:                     84.52
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):           5.36e-36
# Time:                        16:31:47   Log-Likelihood:                -25091.
# No. Observations:                2054   AIC:                         5.019e+04
# Df Residuals:                    2051   BIC:                         5.020e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -1.074e+04   3883.598     -2.766      0.006   -1.84e+04   -3127.755
# Environmental   481.0699     43.388     11.088      0.000     395.980     566.160
# Governance      162.2229     60.329      2.689      0.007      43.910     280.536
# ==============================================================================
# Omnibus:                     2096.910   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           118128.350
# Skew:                           4.996   Prob(JB):                         0.00
# Kurtosis:                      38.783   Cond. No.                         313.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 183.07999999999998%
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     55.07
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):           5.06e-24
# Time:                        16:31:47   Log-Likelihood:                -25118.
# No. Observations:                2054   AIC:                         5.024e+04
# Df Residuals:                    2051   BIC:                         5.026e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.068e+04   4653.140     -4.444      0.000   -2.98e+04   -1.16e+04
# Social       477.7667     59.142      8.078      0.000     361.783     593.750
# Governance   247.9231     60.104      4.125      0.000     130.051     365.795
# ==============================================================================
# Omnibus:                     2098.392   Durbin-Watson:                   1.939
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           115206.289
# Skew:                           5.015   Prob(JB):                         0.00
# Kurtosis:                      38.292   Cond. No.                         393.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 184.23000000000002%
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.077
# Model:                            OLS   Adj. R-squared:                  0.075
# Method:                 Least Squares   F-statistic:                     56.81
# Date:                Sun, 04 Dec 2022   Prob (F-statistic):           2.84e-35
# Time:                        16:31:47   Log-Likelihood:                -25090.
# No. Observations:                2054   AIC:                         5.019e+04
# Df Residuals:                    2050   BIC:                         5.021e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -1.379e+04   4679.823     -2.948      0.003    -2.3e+04   -4617.099
# Environmental   436.6374     57.698      7.568      0.000     323.485     549.790
# Social           90.6427     77.596      1.168      0.243     -61.533     242.818
# Governance      156.6939     60.509      2.590      0.010      38.028     275.360
# ==============================================================================
# Omnibus:                     2099.284   Durbin-Watson:                   1.941
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           118516.538
# Skew:                           5.005   Prob(JB):                         0.00
# Kurtosis:                      38.841   Cond. No.                         472.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Error = 183.35%

# %%
summary=pd.DataFrame()
summary['Adjusted R']=(r1,r2,r3,r4,r5,r6,r7)
summary['Error']=(e1,e2,e3,e4,e5,e6,e7)
summary['F-statistic']=(f1,f2,f3,f4,f5,f6,f7)
summary
# Out:
#    Adjusted R     Error  F-statistic
# 0       0.072  1.834159       161.30
# 1       0.043  1.850677        92.40
# 2       0.020  1.837348        43.51
# 3       0.073  1.836752        81.63
# 4       0.075  1.830846        84.52
# 5       0.050  1.842300        55.07
# 6       0.075  1.833514        56.81

# %% [markdown]
# By compairing Adujusted R-square, Error and F-statistic of each model, the 5th model is the best choice.
#
# The best prediction model for US is: Revenue = -10740 + 481.0699 * Environmental Pillar Score + 162.2229 * Governance Pillar Score

# %% [markdown]
# # Summary

# %% [markdown]
# prediction model is: Revenue = -10380 + 414.3789 * Environmental Pillar Score + 192.4745 * Governance Pillar Score
#
# prediction model for Ireland is: Revenue = -12690 + 349.2537 * Environmental Pillar Score + 175.7489 * Governance Pillar Score
#
# prediction model for UK is: Revenue = -14750 + 174.0372 * Environmental Pillar Score + 310.9630 * Governance Pillar Score
#
# prediction model for US is: Revenue = -10740 + 481.0699 * Environmental Pillar Score + 162.2229 * Governance Pillar Score

# %% [markdown]
# All the best perdiction model predicts the financial performance by the Environmental Pillar Score and Governance Pillar Score, without using the Social Pillar Score

# %% [markdown]
# Most of the models perdicts by having a much higher coefficient for the Environmental Pillar Score than the Governance Pillar Score, only UK has a higher coefficient for the Governance Pillar Score in the 4 models.
# While in the other 3 models, US has the highest coefficient for the Environmental Pillar Score and Ireland has the lowest, and their coefficient for the Governance Pillar Score are relatively close.
