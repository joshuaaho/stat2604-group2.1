# %%
import numpy as np
import eikon as ek
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# ek.set_app_key('153df6af7d1f4a1daa64764ffe8b0a61191847a4')

# %%
# The commented out code is code used to create the dataset from the API + some data preprocessing done
# You dont need to run this as the dataset has already been generated.

# company_tickers = list(pd.read_csv("data/company_tickers.csv")["Identifier"])
# company_tickers = company_tickers[1:]
# df = ek.get_data(company_tickers, ["TR.ROAMean(Period=FY0),TR.EnvironmentPillarScore(Period=FY0),TR.SocialPillarScore(Period=FY0),TR.GovernancePillarScore(Period=FY0),TR.TotalAssetsReported(Period=FY0),TR.TotalDebtOutstanding(Period=FY0),TR.TotalEquity(Period=FY0),TR.BoardSize(Period=FY0),TR.AnalyticBoardFemale(Period=FY0)"])[0]
# df.rename(columns={'Total Assets, Reported':'Firm Size','Return On Assets - Mean': 'ROA','Environmental Pillar Score':'EScore','Social Pillar Score':'SScore','Governance Pillar Score':'GScore', 'Board Gender Diversity, Percent':'Board Diversity'}, inplace=True)
# df = df.dropna()
# df["Firm Size"] =  np.log(df["Firm Size"])
# df["Leverage Ratio"] = df["Total Debt"] / df["Total Equity"]
# df["EScore * Board Diversity"] = df["EScore"] * df["Board Diversity"]
# df["SScore * Board Diversity"] = df["SScore"] * df["Board Diversity"]
# df["GScore * Board Diversity"] = df["GScore"] * df["Board Diversity"]
# df["Year"] = 2021
# df["Instrument"] = df.index
# df.to_csv("data/obj4_dataframe_1.csv",index= False)

# DataFrame with some data preprocessing done
df = pd.read_csv("data/obj4_dataframe_1.csv")
df.index = df["Instrument"]
df
# Out:
#             Instrument       ROA     EScore     SScore     GScore  Firm Size  \
# Instrument
# 0                    0  14.93988  48.988241  50.099376  53.226852  23.037819
# 1                    1   0.64978  69.024097  91.307613  93.898810  27.713273
# 2                    2   0.60250  83.155311  81.008728  64.864418  27.645119
# 3                    3   2.49129  62.523242  71.748851  88.609286  23.902153
# 4                    4   9.14688  80.176020  72.304933  87.403219  22.794133
# ...                ...       ...        ...        ...        ...        ...
# 2308              2308 -20.95000   0.000000  21.752228   5.891294  23.827583
# 2310              2310  14.43333   0.000000  37.751975  66.852050  21.988337
# 2312              2312   4.80000  84.024831  90.638585  88.765858  24.726956
# 2320              2320   9.99233  34.242736  70.173662  84.914414  23.954547
# 2321              2321   0.29333  86.363874  83.628339  84.719136  27.351086
#
#               Total Debt  Total Equity  Board Size  Board Diversity  \
# Instrument
# 0             2785100000    6022700000           7        42.857143
# 1           149186000000   65907000000           8        37.500000
# 2           228975000000   70452000000          12        33.333333
# 3             3390000000    9997000000          10        40.000000
# 4             2875500000    2451100000          11        36.363636
# ...                  ...           ...         ...              ...
# 2308          1226000000   19514000000           9        22.222222
# 2310              982910    3092440910           9        22.222222
# 2312         15848000000   15920000000          20        30.000000
# 2320         13225223000    7617090000           7        14.285714
# 2321        236580000000   43954000000          14        35.714286
#
#             Leverage Ratio  EScore * Board Diversity  \
# Instrument
# 0                 0.462434               2099.496062
# 1                 2.263584               2588.403644
# 2                 3.250085               2771.843713
# 3                 0.339102               2500.929693
# 4                 1.173147               2915.491649
# ...                    ...                       ...
# 2308              0.062827                  0.000000
# 2310              0.000318                  0.000000
# 2312              0.995477               2520.744925
# 2320              1.736257                489.181946
# 2321              5.382445               3084.424080
#
#             SScore * Board Diversity  GScore * Board Diversity  Year
# Instrument
# 0                        2147.116124               2281.150794  2021
# 1                        3424.035483               3521.205357  2021
# 2                        2700.290941               2162.147266  2021
# 3                        2869.954049               3544.371453  2021
# 4                        2629.270309               3178.298862  2021
# ...                              ...                       ...   ...
# 2308                      483.382853                130.917642  2021
# 2310                      838.932770               1485.601109  2021
# 2312                     2719.157544               2662.975734  2021
# 2320                     1002.480885               1213.063063  2021
# 2321                     2986.726390               3025.683439  2021
#
# [2150 rows x 15 columns]

# %%
# The commented out code is code used to create the dataset from the API + some data preprocessing done
# You dont need to run this as the dataset has already been generated.

# df2 = ek.get_data(company_tickers, ["TR.ROAMean(Period=FY-1),TR.EnvironmentPillarScore(Period=FY-1),TR.SocialPillarScore(Period=FY-1),TR.GovernancePillarScore(Period=FY-1),TR.TotalAssetsReported(Period=FY-1),TR.TotalDebtOutstanding(Period=FY-1),TR.TotalEquity(Period=FY-1),TR.BoardSize(Period=FY-1),TR.AnalyticBoardFemale(Period=FY-1)"])[0]
# df2.rename(columns={'Total Assets, Reported':'Firm Size','Return On Assets - Mean': 'ROA','Environmental Pillar Score':'EScore','Social Pillar Score':'SScore','Governance Pillar Score':'GScore', 'Board Gender Diversity, Percent':'Board Diversity'}, inplace=True)
# df2 = df2.dropna()
# df2["Firm Size"] =  np.log(df2["Firm Size"])
# df2["Leverage Ratio"] = df2["Total Debt"] / df2["Total Equity"]
# df2["EScore * Board Diversity"] = df2["EScore"] * df2["Board Diversity"]
# df2["SScore * Board Diversity"] = df2["SScore"] * df2["Board Diversity"]
# df2["GScore * Board Diversity"] = df2["GScore"] * df2["Board Diversity"]
# df2["Year"] = 2020
# df2["Instrument"] = df2.index
# df2.to_csv("data/obj4_dataframe_2.csv",index= False)

# DataFrame with some data preprocessing done
df2 = pd.read_csv("data/obj4_dataframe_2.csv")
df2.index = df2["Instrument"]
df2
# Out:
#             Instrument        ROA     EScore     SScore     GScore  Firm Size  \
# Instrument
# 0                    0   11.62886  46.001580  47.770975  42.195623  22.883365
# 1                    1    0.61911  63.981751  91.063681  91.263636  27.609651
# 2                    2    0.65089  80.914087  88.686087  74.378114  27.564750
# 3                    3    3.17883  61.084564  71.252981  86.328924  23.782818
# 4                    4    9.76980  70.152903  63.448766  86.038721  22.737649
# ...                ...        ...        ...        ...        ...        ...
# 2289              2289   -4.70000   4.810629  41.567612  33.940356  22.572193
# 2291              2291 -131.10400  43.944576  36.355115  71.272565  24.677341
# 2300              2300    9.67140   2.756803  24.217118  42.578704  23.099473
# 2320              2320    6.86650  42.924729  65.800888  85.955688  23.740815
# 2321              2321    0.38500  84.367379  80.704668  81.843848  27.415129
#
#               Total Debt  Total Equity  Board Size  Board Diversity  \
# Instrument
# 0           3.525000e+09  3.878900e+09           7        42.857143
# 1           1.323950e+11  6.366500e+10           9        33.333333
# 2           2.017300e+11  7.203500e+10          10        30.000000
# 3           5.228000e+09  9.465000e+09          10        30.000000
# 4           2.463100e+09  2.681300e+09          12        33.333333
# ...                  ...           ...         ...              ...
# 2289        3.640000e+08  4.700000e+09          10        20.000000
# 2291        1.910802e+11 -1.600498e+11           9         0.000000
# 2300        5.493000e+09  3.388000e+09           8        37.500000
# 2320        1.116050e+10  6.052659e+09           8        12.500000
# 2321        2.565790e+11  4.267700e+10          13        23.076923
#
#             Leverage Ratio  EScore * Board Diversity  \
# Instrument
# 0                 0.908763               1971.496264
# 1                 2.079557               2132.725042
# 2                 2.800444               2427.422603
# 3                 0.552351               1832.536919
# 4                 0.918622               2338.430113
# ...                    ...                       ...
# 2289              0.077447                 96.212571
# 2291             -1.193879                  0.000000
# 2300              1.621311                103.380098
# 2320              1.843900                536.559115
# 2321              6.012114               1946.939512
#
#             SScore * Board Diversity  GScore * Board Diversity  Year
# Instrument
# 0                        2047.327502               1808.383838  2020
# 1                        3035.456028               3042.121212  2020
# 2                        2660.582611               2231.343434  2020
# 3                        2137.589421               2589.867725  2020
# 4                        2114.958856               2867.957351  2020
# ...                              ...                       ...   ...
# 2289                      831.352245                678.807119  2020
# 2291                        0.000000                  0.000000  2020
# 2300                      908.141927               1596.701389  2020
# 2320                      822.511102               1074.446098  2020
# 2321                     1862.415404               1888.704177  2020
#
# [2103 rows x 15 columns]

# %%
# The commented out code is code used to create the dataset from the API + some data preprocessing done
# You dont need to run this as the dataset has already been generated.

# df3 = ek.get_data(company_tickers, ["TR.ROAMean(Period=FY-2),TR.EnvironmentPillarScore(Period=FY-2),TR.SocialPillarScore(Period=FY-2),TR.GovernancePillarScore(Period=FY-2),TR.TotalAssetsReported(Period=FY-2),TR.TotalDebtOutstanding(Period=FY-2),TR.TotalEquity(Period=FY-2),TR.BoardSize(Period=FY-2),TR.AnalyticBoardFemale(Period=FY-2)"])[0]
# df3.rename(columns={'Total Assets, Reported':'Firm Size','Return On Assets - Mean': 'ROA','Environmental Pillar Score':'EScore','Social Pillar Score':'SScore','Governance Pillar Score':'GScore', 'Board Gender Diversity, Percent':'Board Diversity'}, inplace=True)
# df3 = df3.dropna()
# df3["Firm Size"] =  np.log(df3["Firm Size"])
# df3["Leverage Ratio"] = df3["Total Debt"] / df3["Total Equity"]
# df3["EScore * Board Diversity"] = df3["EScore"] * df3["Board Diversity"]
# df3["SScore * Board Diversity"] = df3["SScore"] * df3["Board Diversity"]
# df3["GScore * Board Diversity"] = df3["GScore"] * df3["Board Diversity"]
# df3["Year"] = 2019
# df3["Instrument"] = df3.index
# df3.to_csv("data/obj4_dataframe_3.csv",index=False)

# # DataFrame with some data preprocessing done
df3 = pd.read_csv("data/obj4_dataframe_3.csv")
df3.index = df3["Instrument"]
df3
# Out:
#             Instrument       ROA     EScore     SScore     GScore  Firm Size  \
# Instrument
# 0                    0   9.98850  45.045682  34.326361  68.424092  22.784047
# 1                    1   0.38000  65.507210  90.434776  94.177646  27.672437
# 2                    2   0.34775  83.812035  88.553713  77.527481  27.538847
# 3                    3   3.97450  47.104666  62.509519  91.365993  23.955650
# 4                    4   8.79440  64.858002  63.971785  79.897604  22.680992
# ...                ...       ...        ...        ...        ...        ...
# 2239              2239  14.40333  54.138502  18.426645  62.324172  23.815907
# 2246              2246   7.64100  46.103723  49.418706  35.870881  23.019333
# 2247              2247  10.99125  56.599233  30.563218  24.633700  27.903324
# 2320              2320   7.74400  42.514377  69.749089  81.369106  23.688176
# 2321              2321   0.42875  83.487861  83.343072  81.572483  27.391869
#
#               Total Debt  Total Equity  Board Size  Board Diversity  \
# Instrument
# 0           3.519200e+09  3.155200e+09           7        42.857143
# 1           1.381140e+11  6.128700e+10           8        37.500000
# 2           2.065780e+11  6.802300e+10          11        36.363636
# 3           6.852000e+09  1.233300e+10           9        22.222222
# 4           2.517700e+09  2.756400e+09          12        25.000000
# ...                  ...           ...         ...              ...
# 2239        6.264600e+09  1.054300e+10           9        22.222222
# 2246        1.039755e+09  7.767063e+09          12        33.333333
# 2247        1.254300e+11  7.645040e+11          11         9.090909
# 2320        1.002219e+10  5.447532e+09           9        11.111111
# 2321        2.481420e+11  4.364400e+10          13        23.076923
#
#             Leverage Ratio  EScore * Board Diversity  \
# Instrument
# 0                 1.115365               1930.529217
# 1                 2.253561               2456.520377
# 2                 3.036885               3047.710359
# 3                 0.555583               1046.770359
# 4                 0.913402               1621.450046
# ...                    ...                       ...
# 2239              0.594195               1203.077814
# 2246              0.133867               1536.790780
# 2247              0.164067                514.538478
# 2320              1.839767                472.381961
# 2321              5.685593               1926.642937
#
#             SScore * Board Diversity  GScore * Board Diversity  Year
# Instrument
# 0                        1471.129770               2932.461103  2019
# 1                        3391.304094               3531.661719  2019
# 2                        3220.135006               2819.181121  2019
# 3                        1389.100418               2030.355406  2019
# 4                        1599.294636               1997.440108  2019
# ...                              ...                       ...   ...
# 2239                      409.481001               1384.981599  2019
# 2246                     1647.290185               1195.696039  2019
# 2247                      277.847441                223.942724  2019
# 2320                      774.989881                904.101174  2019
# 2321                     1923.301665               1882.441925  2019
#
# [2041 rows x 15 columns]

# %%
# Combine all indicies from each DataFrame
index = list(df.index) + list(df2.index) + list(df3.index)

# %%
# Only use companies whose data are avaliable in all three years
unique, count = np.unique(index, return_counts=True)
unique = unique[count>2]
len(unique)
# Out:
# 1996

# %%
# Extract those companies
df = df.loc[unique]
df2 = df2.loc[unique]
df3 = df3.loc[unique]

# %%
# Combined all observations from the three years
combined_df = pd.concat([df,df2,df3])
combined_df
# Out:
#             Instrument       ROA     EScore     SScore     GScore  Firm Size  \
# Instrument
# 0                    0  14.93988  48.988241  50.099376  53.226852  23.037819
# 1                    1   0.64978  69.024097  91.307613  93.898810  27.713273
# 2                    2   0.60250  83.155311  81.008728  64.864418  27.645119
# 3                    3   2.49129  62.523242  71.748851  88.609286  23.902153
# 4                    4   9.14688  80.176020  72.304933  87.403219  22.794133
# ...                ...       ...        ...        ...        ...        ...
# 2239              2239  14.40333  54.138502  18.426645  62.324172  23.815907
# 2246              2246   7.64100  46.103723  49.418706  35.870881  23.019333
# 2247              2247  10.99125  56.599233  30.563218  24.633700  27.903324
# 2320              2320   7.74400  42.514377  69.749089  81.369106  23.688176
# 2321              2321   0.42875  83.487861  83.343072  81.572483  27.391869
#
#               Total Debt  Total Equity  Board Size  Board Diversity  \
# Instrument
# 0           2.785100e+09  6.022700e+09           7        42.857143
# 1           1.491860e+11  6.590700e+10           8        37.500000
# 2           2.289750e+11  7.045200e+10          12        33.333333
# 3           3.390000e+09  9.997000e+09          10        40.000000
# 4           2.875500e+09  2.451100e+09          11        36.363636
# ...                  ...           ...         ...              ...
# 2239        6.264600e+09  1.054300e+10           9        22.222222
# 2246        1.039755e+09  7.767063e+09          12        33.333333
# 2247        1.254300e+11  7.645040e+11          11         9.090909
# 2320        1.002219e+10  5.447532e+09           9        11.111111
# 2321        2.481420e+11  4.364400e+10          13        23.076923
#
#             Leverage Ratio  EScore * Board Diversity  \
# Instrument
# 0                 0.462434               2099.496062
# 1                 2.263584               2588.403644
# 2                 3.250085               2771.843713
# 3                 0.339102               2500.929693
# 4                 1.173147               2915.491649
# ...                    ...                       ...
# 2239              0.594195               1203.077814
# 2246              0.133867               1536.790780
# 2247              0.164067                514.538478
# 2320              1.839767                472.381961
# 2321              5.685593               1926.642937
#
#             SScore * Board Diversity  GScore * Board Diversity  Year
# Instrument
# 0                        2147.116124               2281.150794  2021
# 1                        3424.035483               3521.205357  2021
# 2                        2700.290941               2162.147266  2021
# 3                        2869.954049               3544.371453  2021
# 4                        2629.270309               3178.298862  2021
# ...                              ...                       ...   ...
# 2239                      409.481001               1384.981599  2019
# 2246                     1647.290185               1195.696039  2019
# 2247                      277.847441                223.942724  2019
# 2320                      774.989881                904.101174  2019
# 2321                     1923.301665               1882.441925  2019
#
# [5988 rows x 15 columns]

# %%
#  Make instrument and year as the index i.e. Each observation can be identified by (year, instrument)

combined_df = combined_df.astype('float')
combined_df = combined_df.set_index(["Instrument","Year"])
table = pd.pivot_table(combined_df, index=["Instrument","Year"])
table
# Out:
#                    Board Diversity  Board Size     EScore  \
# Instrument Year
# 0.0        2019.0        42.857143         7.0  45.045682
#            2020.0        42.857143         7.0  46.001580
#            2021.0        42.857143         7.0  48.988241
# 1.0        2019.0        37.500000         8.0  65.507210
#            2020.0        33.333333         9.0  63.981751
# ...                            ...         ...        ...
# 2320.0     2020.0        12.500000         8.0  42.924729
#            2021.0        14.285714         7.0  34.242736
# 2321.0     2019.0        23.076923        13.0  83.487861
#            2020.0        23.076923        13.0  84.367379
#            2021.0        35.714286        14.0  86.363874
#
#                    EScore * Board Diversity  Firm Size     GScore  \
# Instrument Year
# 0.0        2019.0               1930.529217  22.784047  68.424092
#            2020.0               1971.496264  22.883365  42.195623
#            2021.0               2099.496062  23.037819  53.226852
# 1.0        2019.0               2456.520377  27.672437  94.177646
#            2020.0               2132.725042  27.609651  91.263636
# ...                                     ...        ...        ...
# 2320.0     2020.0                536.559115  23.740815  85.955688
#            2021.0                489.181946  23.954547  84.914414
# 2321.0     2019.0               1926.642937  27.391869  81.572483
#            2020.0               1946.939512  27.415129  81.843848
#            2021.0               3084.424080  27.351086  84.719136
#
#                    GScore * Board Diversity  Leverage Ratio       ROA  \
# Instrument Year
# 0.0        2019.0               2932.461103        1.115365   9.98850
#            2020.0               1808.383838        0.908763  11.62886
#            2021.0               2281.150794        0.462434  14.93988
# 1.0        2019.0               3531.661719        2.253561   0.38000
#            2020.0               3042.121212        2.079557   0.61911
# ...                                     ...             ...       ...
# 2320.0     2020.0               1074.446098        1.843900   6.86650
#            2021.0               1213.063063        1.736257   9.99233
# 2321.0     2019.0               1882.441925        5.685593   0.42875
#            2020.0               1888.704177        6.012114   0.38500
#            2021.0               3025.683439        5.382445   0.29333
#
#                       SScore  SScore * Board Diversity    Total Debt  \
# Instrument Year
# 0.0        2019.0  34.326361               1471.129770  3.519200e+09
#            2020.0  47.770975               2047.327502  3.525000e+09
#            2021.0  50.099376               2147.116124  2.785100e+09
# 1.0        2019.0  90.434776               3391.304094  1.381140e+11
#            2020.0  91.063681               3035.456028  1.323950e+11
# ...                      ...                       ...           ...
# 2320.0     2020.0  65.800888                822.511102  1.116050e+10
#            2021.0  70.173662               1002.480885  1.322522e+10
# 2321.0     2019.0  83.343072               1923.301665  2.481420e+11
#            2020.0  80.704668               1862.415404  2.565790e+11
#            2021.0  83.628339               2986.726390  2.365800e+11
#
#                    Total Equity
# Instrument Year
# 0.0        2019.0  3.155200e+09
#            2020.0  3.878900e+09
#            2021.0  6.022700e+09
# 1.0        2019.0  6.128700e+10
#            2020.0  6.366500e+10
# ...                         ...
# 2320.0     2020.0  6.052659e+09
#            2021.0  7.617090e+09
# 2321.0     2019.0  4.364400e+10
#            2020.0  4.267700e+10
#            2021.0  4.395400e+10
#
# [5988 rows x 13 columns]

# %%
corr = table.corr()
corr = corr.drop(["EScore * Board Diversity","GScore * Board Diversity","SScore * Board Diversity","Total Debt","Total Equity"], axis = 1)
corr = corr.drop(["EScore * Board Diversity","GScore * Board Diversity","SScore * Board Diversity","Total Debt","Total Equity"], axis = 0)

f, ax = plt.subplots(figsize=(12, 10))

# Generate a mask for upper traingle

mask = np.triu(np.ones_like(corr, dtype=bool))

# Configure a custom diverging colormap

cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap

sns.heatmap(corr, annot=True, mask = mask, cmap=cmap)
# Out:
# <AxesSubplot: >

# %%
from linearmodels import PanelOLS
from linearmodels import RandomEffects

# Regression

y = table["ROA"]
table["Const"] = 1
x = ["Board Diversity","Board Size","EScore","EScore * Board Diversity","Firm Size","GScore","GScore * Board Diversity","Leverage Ratio","SScore","SScore * Board Diversity","Const"]
results = PanelOLS(y,table[x]).fit(cov_type='clustered',cluster_entity=True)
results
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                    ROA   R-squared:                        0.0634
# Estimator:                   PanelOLS   R-squared (Between):              0.0908
# No. Observations:                5988   R-squared (Within):              -0.0398
# Date:                Sat, Dec 10 2022   R-squared (Overall):              0.0634
# Time:                        22:10:35   Log-likelihood                -2.068e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      40.443
# Entities:                        1996   P-value                           0.0000
# Avg Obs:                       3.0000   Distribution:                 F(10,5977)
# Min Obs:                       3.0000
# Max Obs:                       3.0000   F-statistic (robust):             17.148
#                                         P-value                           0.0000
# Time periods:                       3   Distribution:                 F(10,5977)
# Avg Obs:                       1996.0
# Min Obs:                       1996.0
# Max Obs:                       1996.0
#
#                                     Parameter Estimates
# ============================================================================================
#                           Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------------------
# Board Diversity             -0.0068     0.0419    -0.1616     0.8717     -0.0888      0.0753
# Board Size                  -0.0664     0.1076    -0.6170     0.5372     -0.2774      0.1446
# EScore                       0.0276     0.0144     1.9127     0.0558     -0.0007      0.0558
# EScore * Board Diversity    -0.0011     0.0006    -1.7801     0.0751     -0.0023      0.0001
# Firm Size                   -0.7912     0.0713    -11.100     0.0000     -0.9309     -0.6515
# GScore                       0.0158     0.0127     1.2450     0.2132     -0.0091      0.0407
# GScore * Board Diversity    -0.0010     0.0005    -2.0002     0.0455     -0.0020  -1.982e-05
# Leverage Ratio               0.0022     0.0036     0.6210     0.5346     -0.0048      0.0093
# SScore                      -0.0344     0.0178    -1.9361     0.0529     -0.0693      0.0004
# SScore * Board Diversity     0.0017     0.0007     2.3705     0.0178      0.0003      0.0031
# Const                        27.664     2.1403     12.925     0.0000      23.468      31.859
# ============================================================================================
#
#
# PanelEffectsResults, id: 0x16d45131a50

# %%
y = (table["Board Diversity"] < 0.3).value_counts()
y = np.array([29,71])
mylabels = ["Companies with more than 30% female in the Board of Directors (29%)","Companies with less than 30% female in the Board of Directors (71%)"]
plt.pie(y, labels = mylabels)
plt.show()

# %%
values = table["Board Size"]
plt.hist(values,bins=100)
plt.ylabel('Number Of Observations') 
plt.xlabel('Board Size (Number of Persons)') 
plt.title("Board Size Among Observations")
# Out:
# Text(0.5, 1.0, 'Board Size Among Observations')

# %%
num_female_board = table["Board Size"] * (table["Board Diversity"] / 100)
m = round(num_female_board).groupby(round(num_female_board)).count()
plt.xticks([i for i in range(10)])
plt.bar(m.index,list(m))
plt.ylabel('Number Of Observations') 
plt.xlabel('Number of Females') 
plt.title("Number of Females in Board of Directors Among Observations")
three_or_more_females = m[[0,1,2,3]].sum() / m.sum()
three_or_more_females
# Out:
# 0.7448229792919172
